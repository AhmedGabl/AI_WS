# %% [markdown]
# # Getting Started with OpenCV

# %% [markdown]
# > ### A. Installing OpenCV

# %% [markdown]
# #### For Windows users
#
#
#
# - Go to [this website](https://www.lfd.uci.edu/~gohlke/pythonlibs/#opencv). It contains the 'wheel files' for several packages, which are present with a .whl extension. Do a Ctrl-F and find the ones for OpenCV.
#
# - Download the .whl file appropriate to your *Python version* and *OS specifications* (most likely, you will be using a Python version greater than 3.4, so use that)
#
# - Navigate to the file where the .whl file is present
#
# - Make sure you have `pip` present on your machine. [This tutorial page](https://pythonprogramming.net/using-pip-install-for-python-modules/) can help you install `pip` if you don't have it.
#
# - Run the following code:
#
# `pip install wheel-name.whl`
#
# - If pip is not present in your PATH variables, you may have to point to where pip is installed:
#
# `C:\Python34\Scripts\Pip install <wheel-name>.whl`
#
#
#
# #### For Mac users
#
# - Open Terminal
#
# - Run the following command
#
# `apt-get install python3-OpenCV`

# %% [markdown]
# #### For conda installation
#
# If you are running Python via Anaconda, you can run a simple conda install:
#
# `conda install opencv`

# %% [markdown]
# > ### B. Importing OpenCV

# %% [markdown]
# > ### C. Working with Images using OpenCV

# %% [markdown]
# Once you have installed OpenCV, you can experiment with images

# %%
# First, import OpenCV. The Python name for this is 'cv2'
import cv2

# %%
# Run these if OpenCV doesn't load
import sys
#sys.path.append('/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/cv2/')

# %%
# Next, import libraries that will aid OpenCV
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Let's do some basic operations using OpenCV
# Reading an image
img = cv2.imread('/kaggle/input/style-transfer-and-object-detection/rabbit.jpg')# You can replace this file path by your own file path.
print (img.shape)
# Out:
# (900, 1440, 3)

# %%
img1 = cv2.imread('/kaggle/input/style-transfer-and-object-detection/crystal-kpop-girl-bw-wallpaper-preview.jpg')# You can replace this file path by your own file path.
print (img1.shape)
# Out:
# (455, 728, 3)

# %% [markdown]
# This 'img' object becomes the basic object which is manipulated

# %% [markdown]
# The cv2.imshow() function is the standard way to show images using cv2.
#
# However, this opens up a new window, which sometimes doesn't work with Jupyter notebooks.
#
# Hence, the **suggested way with to show images with Jupyter notebooks** is using matplotlib's inline functions. These are demonstrated below.

# %%
# Using cv2's imshow opens this image in a different window.
# However, the easier and more presentable way to do this is by using matplotlib's inline function
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB)) # converting BGR to RGB for using matplotlib
plt.axis('off')
plt.show()

# %% [markdown]
# Let's now move to working with channels and colours.
# As you know, coloured images typically have 3 channels - Red, Green, Blue (RGB). For OpenCV specifically, this ordering of channels is B-G-R. Let's manipulate these images according to their channels.

# %%
# Now, let's say we want to demonstrate only the green channel out of these
# The ordering of channels in OpenCV is B-G-R. 0 is Blue, 1 is Green, 2 is Red.
plt.imshow(img[:,:,1])
plt.axis('off')
plt.show()

# %%
# This image is a colour image. We can easily convert this image to gray.
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img_gray, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# # Image Resize

# %%
img = cv2.imread('../input/style-transfer-and-object-detection/rabbit.jpg')
# Resize image
import cv2
import matplotlib.pyplot as plt


# Resize image (example, adjust as needed)
resized_image = cv2.resize(img_gray, (256,256))

# %% [markdown]
# # Normalize image

# %%
# Normalize image
normalized_image = resized_image / 255.0
normalized_image = normalized_image.astype(np.float32)
# Show the normalized image
plt.imshow(normalized_image, cmap='gray')
plt.axis('off')
plt.title('Normalized Image')
plt.show()

# %% [markdown]
# # Apply Gaussian blur

# %%
# Apply Gaussian blur
blurred_image = cv2.GaussianBlur(normalized_image, (5, 5), 0)  # Adjust kernel size (5,5) and sigma (0) as needed

# Show the blurred image
plt.imshow(blurred_image, cmap='gray')
plt.axis('off')
plt.title('Blurred Image')
plt.show()

# %% [markdown]
# # Apply median blur

# %%
# Apply median blur
median_blurred_image = cv2.medianBlur(normalized_image, 5)  # Adjust kernel size (5) as needed

# Show the median blurred image
plt.imshow(median_blurred_image, cmap='gray')
plt.axis('off')
plt.title('Median Blurred Image')
plt.show()

# Print the median blurred image array (optional)
median_blurred_image
# Out:
# array([[0.14117648, 0.14117648, 0.14117648, ..., 0.16078432, 0.15686275,
#         0.15686275],
#        [0.14117648, 0.14117648, 0.14117648, ..., 0.16470589, 0.15686275,
#         0.15686275],
#        [0.14509805, 0.14117648, 0.14509805, ..., 0.16470589, 0.16078432,
#         0.15686275],
#        ...,
#        [0.05882353, 0.09803922, 0.11764706, ..., 0.18039216, 0.15686275,
#         0.14901961],
#        [0.05882353, 0.09803922, 0.11764706, ..., 0.18431373, 0.18431373,
#         0.16470589],
#        [0.05490196, 0.09803922, 0.11764706, ..., 0.18431373, 0.18431373,
#         0.18431373]], dtype=float32)

# %% [markdown]
# # Edge detection

# %%
# gray image
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray_img, 100, 200)

# %%
plt.imshow(edges )
plt.axis('off')
plt.show()

# %% [markdown]
# # Histogram Equalization

# %%
# Convert to grayscale
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Apply histogram equalization
equalized_image = cv2.equalizeHist(gray_image)

# Display the equalized image and its histogram side-by-side
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

axes[0].imshow(equalized_image)
axes[0].axis('off')
axes[0].set_title('Histogram Equalized Image')

axes[1].hist(equalized_image.ravel(), 256, [0, 256])
axes[1].set_title('Histogram')

plt.show()

# %% [markdown]
# # Basic Image Arithmetic

# %%
# prompt: Basic Image Arithmetic

# Basic Image Arithmetic

# Load images (replace with your image paths)
img1 = cv2.imread('/kaggle/input/style-transfer-and-object-detection/rabbit.jpg')
img2 = cv2.imread('/kaggle/input/style-transfer-and-object-detection/crystal-kpop-girl-bw-wallpaper-preview.jpg')

# Resize images to the same dimensions for arithmetic operations
img1 = cv2.resize(img1, (256, 256))
img2 = cv2.resize(img2, (256, 256))


# Addition
added_image = cv2.add(img1, img2)
plt.imshow(cv2.cvtColor(added_image, cv2.COLOR_BGR2RGB))
plt.title("Added Image")
plt.axis('off')
plt.show()

# Subtraction
subtracted_image = cv2.subtract(img1, img2)
plt.imshow(cv2.cvtColor(subtracted_image, cv2.COLOR_BGR2RGB))
plt.title("Subtracted Image")
plt.axis('off')
plt.show()

# Weighted addition
weighted_addition = cv2.addWeighted(img1, 0.6, img2, 0.4, 0)  # Adjust weights as needed
plt.imshow(cv2.cvtColor(weighted_addition, cv2.COLOR_BGR2RGB))
plt.title("Weighted Addition")
plt.axis('off')
plt.show()
